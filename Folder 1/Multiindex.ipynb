# %%
import pandas as pd

# %%
pd.read_csv('./pandas/bigmac.csv')
# Out:
#        Date        Country  Price in US Dollars
# 0    1/2016      Argentina                 2.39
# 1    1/2016      Australia                 3.74
# 2    1/2016         Brazil                 3.35
# 3    1/2016        Britain                 4.22
# 4    1/2016         Canada                 4.14
# ..      ...            ...                  ...
# 647  1/2010         Turkey                 3.83
# 648  1/2010            UAE                 2.99
# 649  1/2010        Ukraine                 1.83
# 650  1/2010  United States                 3.58
# 651  1/2010        Uruguay                 3.32
#
# [652 rows x 3 columns]

# %%
## Parse_date is used to take date column into date format
bigmac = pd.read_csv('./pandas/bigmac.csv',parse_dates=['Date'])

# %%
bigmac.head(3)
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74
# 2 2016-01-01     Brazil                 3.35

# %%
bigmac.dtypes
# Out:
# Date                   datetime64[ns]
# Country                        object
# Price in US Dollars           float64
# dtype: object

# %%
bigmac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 652 non-null    datetime64[ns]
#  1   Country              652 non-null    object
#  2   Price in US Dollars  652 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 15.4+ KB

# %% [markdown]
# ## Create Multiindex with setindex method()

# %%
bigmac = pd.read_csv('./pandas/bigmac.csv',parse_dates=['Date'])
bigmac.head(2)
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74

# %%
bigmac.set_index('Date') # Date column is set as index column
# Out:
#                   Country  Price in US Dollars
# Date
# 2016-01-01      Argentina                 2.39
# 2016-01-01      Australia                 3.74
# 2016-01-01         Brazil                 3.35
# 2016-01-01        Britain                 4.22
# 2016-01-01         Canada                 4.14
# ...                   ...                  ...
# 2010-01-01         Turkey                 3.83
# 2010-01-01            UAE                 2.99
# 2010-01-01        Ukraine                 1.83
# 2010-01-01  United States                 3.58
# 2010-01-01        Uruguay                 3.32
#
# [652 rows x 2 columns]

# %%
bigmac.set_index(keys='Country')  # now setting country as index columns
# Out:
#                     Date  Price in US Dollars
# Country
# Argentina     2016-01-01                 2.39
# Australia     2016-01-01                 3.74
# Brazil        2016-01-01                 3.35
# Britain       2016-01-01                 4.22
# Canada        2016-01-01                 4.14
# ...                  ...                  ...
# Turkey        2010-01-01                 3.83
# UAE           2010-01-01                 2.99
# Ukraine       2010-01-01                 1.83
# United States 2010-01-01                 3.58
# Uruguay       2010-01-01                 3.32
#
# [652 rows x 2 columns]

# %%
## We can aslo set multiple indexes

bigmac.set_index(keys=['Date','Country'],inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35

# %%
bigmac.sort_index(inplace=True)

# %%
bigmac.head(2)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98

# %%
bigmac.index
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
type(bigmac.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
bigmac.index[0]
# Out:
# (Timestamp('2010-01-01 00:00:00'), 'Argentina')

# %% [markdown]
# # Get level values method()

# %%
bigmac = pd.read_csv('./pandas/bigmac.csv',parse_dates=['Date'],index_col=['Date','Country'])
bigmac.sort_index(inplace=True)
bigmac.head(2)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98

# %%
bigmac.index
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
bigmac.index.get_level_values(0) ## getting values of first parameter of df that is dates
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
bigmac.index.get_level_values(1) # values of second parameters
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %%
bigmac.index.get_level_values(2) # values of 3rd parameter from df..but will not get this as only 2 indexes are mentioned
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_level_number(self, level)
#    1294         try:
# -> 1295             level = self.names.index(level)
#    1296         except ValueError:
#
# ValueError: 2 is not in list
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-d803b0411f54> in <module>
# ----> 1 bigmac.index.get_level_values(2) # values of 3rd parameter from df
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_level_values(self, level)
#    1591         Index(['d', 'e', 'f'], dtype='object', name='level_2')
#    1592         """
# -> 1593         level = self._get_level_number(level)
#    1594         values = self._get_level_values(level)
# ...

# %%
bigmac.index.get_level_values('Date')
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
bigmac.index.get_level_values('Country')
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %% [markdown]
# # .Set Name() Method on multiindex

# %%
bigmac = pd.read_csv('./pandas/bigmac.csv',parse_dates=['Date'],index_col=['Date','Country'])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
bigmac.index.set_names(['Day','Location'],inplace=True) ## names of columns will change

# %%
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Day        Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %% [markdown]
# # .sort_index() Method

# %%
bigmac = pd.read_csv('./pandas/bigmac.csv',parse_dates=['Date'],index_col=['Date','Country'])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.sort_index(ascending=True)
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
bigmac.sort_index(ascending=False)
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Vietnam                       2.67
#            Venezuela                     0.66
#            Uruguay                       3.74
#            United States                 4.93
#            Ukraine                       1.54
# ...                                       ...
# 2010-01-01 Canada                        3.97
#            Britain                       3.67
#            Brazil                        4.76
#            Australia                     3.98
#            Argentina                     1.84
#
# [652 rows x 1 columns]

# %%
bigmac.sort_index(ascending=[True,False],inplace=True)

# %%
bigmac.head(3)
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Uruguay                       3.32
#            United States                 3.58
#            Ukraine                       1.83

# %% [markdown]
# # Extract Rows from multiindex DataFrame

# %%
bigmac = pd.read_csv('./pandas/bigmac.csv',parse_dates=['Date'],index_col=['Date','Country'])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.loc[('2010-01-01','Brazil'),'Price in US Dollars']
# Out:
# Date        Country
# 2010-01-01  Brazil     4.76
# Name: Price in US Dollars, dtype: float64

# %%
bigmac.loc[('2015-07-01','China'),'Price in US Dollars']
# Out:
# Date        Country
# 2015-07-01  China      2.74
# Name: Price in US Dollars, dtype: float64

# %% [markdown]
# ## Transpose method

# %%
bigmac = pd.read_csv('./pandas/bigmac.csv',parse_dates=['Date'],index_col=['Date','Country'])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac = bigmac.transpose()
bigmac.head(1)
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %% [markdown]
# # Swaplevel Method

# %%
bigmac = pd.read_csv('./pandas/bigmac.csv',parse_dates=['Date'],index_col=['Date','Country'])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.swaplevel() # this will swap the postions of index lable.
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2010-01-01                 1.84
# Australia     2010-01-01                 3.98
# Brazil        2010-01-01                 4.76
# Britain       2010-01-01                 3.67
# Canada        2010-01-01                 3.97
# ...                                       ...
# Ukraine       2016-01-01                 1.54
# United States 2016-01-01                 4.93
# Uruguay       2016-01-01                 3.74
# Venezuela     2016-01-01                 0.66
# Vietnam       2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %% [markdown]
# # .Stack() Method

# %%
world = pd.read_csv('./pandas/worldstats.csv',index_col=['country','year'])

# %%
world.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
world.stack()
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                                     ...
# Zimbabwe    1962  GDP           1.117602e+09
#             1961  Population    3.876638e+06
#                   GDP           1.096647e+09
#             1960  Population    3.752390e+06
#                   GDP           1.052990e+09
# Length: 22422, dtype: float64

# %%
world.stack().to_frame()
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
# ...                                  ...
# Zimbabwe   1962 GDP         1.117602e+09
#            1961 Population  3.876638e+06
#                 GDP         1.096647e+09
#            1960 Population  3.752390e+06
#                 GDP         1.052990e+09
#
# [22422 rows x 1 columns]

# %% [markdown]
# # Unstack Method

# %%
# considering above data

# %%
s = world.stack()
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
s.unstack()
# Out:
#                   Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08
#             1963   9531555.0  7.511112e+08
#             1964   9728645.0  8.000000e+08
# ...                      ...           ...
# Zimbabwe    2011  14255592.0  1.095623e+10
#             2012  14565482.0  1.239272e+10
#             2013  14898092.0  1.349023e+10
#             2014  15245855.0  1.419691e+10
#             2015  15602751.0  1.389294e+10
#
# [11211 rows x 2 columns]

# %%
s.unstack().unstack().unstack()
# Out:
#             year  country
# Population  1960  Afghanistan           8.994793e+06
#                   Albania                        NaN
#                   Algeria               1.112489e+07
#                   Andorra                        NaN
#                   Angola                         NaN
#                                             ...
# GDP         2015  West Bank and Gaza    1.267740e+10
#                   World                 7.343364e+13
#                   Yemen, Rep.                    NaN
#                   Zambia                2.120156e+10
#                   Zimbabwe              1.389294e+10
# Length: 28224, dtype: float64

# %%
s.unstack(-1)
# Out:
#                   Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08
#             1963   9531555.0  7.511112e+08
#             1964   9728645.0  8.000000e+08
# ...                      ...           ...
# Zimbabwe    2011  14255592.0  1.095623e+10
#             2012  14565482.0  1.239272e+10
#             2013  14898092.0  1.349023e+10
#             2014  15245855.0  1.419691e+10
#             2015  15602751.0  1.389294e+10
#
# [11211 rows x 2 columns]

# %% [markdown]
# # Pivot Method

# %%
sales = pd.read_csv('./pandas/salesmen.csv',parse_dates=['Date'])

# %%
sales.head(3)
# Out:
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982

# %%
sales['Salesman'].value_counts()
# Out:
# Ronald    366
# Oscar     366
# Dave      366
# Bob       366
# Jeb       366
# Name: Salesman, dtype: int64

# %%
sales['Salesman'] = sales['Salesman'].astype('category')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1830 entries, 0 to 1829
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1830 non-null   datetime64[ns]
#  1   Salesman  1830 non-null   category
#  2   Revenue   1830 non-null   int64
# dtypes: category(1), datetime64[ns](1), int64(1)
# memory usage: 30.7 KB

# %%
sales.pivot(index='Date',columns='Salesman',values='Revenue')
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771
# ...          ...   ...   ...    ...     ...
# 2016-12-27  2045  2843  6666    835    2981
# 2016-12-28   100  8888  1243   3073    6129
# 2016-12-29  4115  9490  3498   6424    7662
# 2016-12-30  2577  3594  8858   7088    2570
# 2016-12-31  3845  6830  9717   8408    2619
#
# [366 rows x 5 columns]

# %% [markdown]
# # Pivote Table Method

# %%
foods = pd.read_csv('./pandas/foods.csv')
foods.head(3)
# Out:
#   First Name  Gender      City Frequency     Item  Spend
# 0      Wanda  Female  Stamford    Weekly   Burger  15.66
# 1       Eric    Male  Stamford     Daily  Chalupa  10.56
# 2    Charles    Male  New York     Never    Sushi  42.14

# %%
foods.pivot_table(values='Spend',index='Gender',aggfunc='mean')
# Out:
#             Spend
# Gender
# Female  50.709629
# Male    49.397623

# %%
foods.pivot_table(values='Spend',index='Gender',aggfunc='sum')
# Out:
#            Spend
# Gender
# Female  25963.33
# Male    24106.04

# %%
foods.pivot_table(values='Spend',index='Item',aggfunc='mean')
# Out:
#                Spend
# Item
# Burger     49.780321
# Burrito    49.228810
# Chalupa    52.003537
# Donut      46.838289
# Ice Cream  50.494261
# Sushi      52.668253

# %%
foods.pivot_table(values='Spend',index=['Gender','Item'],aggfunc='sum')
# Out:
#                     Spend
# Gender Item
# Female Burger     4094.30
#        Burrito    4257.82
#        Chalupa    4152.26
#        Donut      4743.00
#        Ice Cream  4032.87
#        Sushi      4683.08
# Male   Burger     3671.43
#        Burrito    4012.62
#        Chalupa    3492.26
#        Donut      4015.76
#        Ice Cream  4854.12
#        Sushi      4059.85

# %%
foods.pivot_table(values='Spend',index=['Gender','Item'],columns='City',aggfunc='sum')
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger      1239.04       1639.24   1216.02
#        Burrito      978.95       1458.76   1820.11
#        Chalupa      876.58       1673.33   1602.35
#        Donut       1446.78       1639.26   1656.96
#        Ice Cream   1521.62       1479.22   1032.03
#        Sushi       1480.29       1742.88   1459.91
# Male   Burger      1294.09        938.18   1439.16
#        Burrito     1399.40       1312.93   1300.29
#        Chalupa     1227.77       1114.23   1150.26
#        Donut       1345.27       1249.36   1421.13
#        Ice Cream   1603.63       2191.27   1059.22
#        Sushi       1396.15       1395.88   1267.82

# %%
foods.pivot_table(values='Spend',index=['Gender','Item'],columns=['Frequency','City'],aggfunc='sum')
# Out:
# Frequency           Daily                        Monthly               \
# City             New York Philadelphia Stamford New York Philadelphia
# Gender Item
# Female Burger      262.67       231.68   144.66   171.86       215.05
#        Burrito     224.45       321.57   195.63   122.74        34.28
#        Chalupa      43.19        23.49    95.70   158.37       289.96
#        Donut       478.10       247.40   124.35   284.53        50.25
#        Ice Cream   262.19       177.69    92.88    92.53        74.51
#        Sushi        81.07       348.53   393.27    93.16        78.71
# Male   Burger      319.46       112.70   197.72   187.29       213.14
#        Burrito     236.21       165.76   276.23   147.54        89.58
#        Chalupa      54.09       274.81   192.64   333.76        90.70
#        Donut       230.00       190.71   129.42   183.73       259.29
#        Ice Cream   178.22       148.69    15.17   152.20       386.55
# ...

# %%
foods.pivot_table(values='Spend',index=['Gender','Item'],columns='City',aggfunc='count')
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger           24            31        27
#        Burrito          23            28        34
#        Chalupa          19            32        25
#        Donut            31            30        34
#        Ice Cream        27            32        22
#        Sushi            31            30        32
# Male   Burger           22            21        31
#        Burrito          25            30        28
#        Chalupa          25            23        23
#        Donut            30            33        29
#        Ice Cream        29            41        25
#        Sushi            27            28        18

# %%
foods.pivot_table(values='Spend',index=['Gender','Item'],columns='City',aggfunc='max')
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger        98.96         97.79     85.06
#        Burrito       92.25         96.79     99.21
#        Chalupa       98.43         99.29     98.78
#        Donut         95.63         96.52     91.75
#        Ice Cream     97.83         88.14     97.44
#        Sushi         99.51         99.02     95.43
# Male   Burger        90.32         99.68     97.20
#        Burrito       98.04         93.27     95.07
#        Chalupa       96.44         98.40     99.87
#        Donut         86.70         93.12     99.26
#        Ice Cream     97.65         99.24     99.17
#        Sushi         93.85         97.12     98.48

# %%
pd.pivot_table(data=foods,values='Spend',index=['Gender','Item'],columns='City',aggfunc='count')
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger           24            31        27
#        Burrito          23            28        34
#        Chalupa          19            32        25
#        Donut            31            30        34
#        Ice Cream        27            32        22
#        Sushi            31            30        32
# Male   Burger           22            21        31
#        Burrito          25            30        28
#        Chalupa          25            23        23
#        Donut            30            33        29
#        Ice Cream        29            41        25
#        Sushi            27            28        18

# %% [markdown]
# # .pd Melt () method

# %%
sales = pd.read_csv('./pandas/quarters.csv')

# %%
sales.head(3)
# Out:
#   Salesman      Q1      Q2      Q3      Q4
# 0    Boris  602908  233879  354479   32704
# 1      Bob   43790  514863  297151  544493
# 2    Tommy  392668  113579  430882  247231

# %%
#
pd.melt(frame=sales,id_vars='Salesman')
# Out:
#    Salesman variable   value
# 0     Boris       Q1  602908
# 1       Bob       Q1   43790
# 2     Tommy       Q1  392668
# 3    Travis       Q1  834663
# 4    Donald       Q1  580935
# 5       Ted       Q1  656644
# 6       Jeb       Q1  486141
# 7     Stacy       Q1  479662
# 8    Morgan       Q1  992673
# 9     Boris       Q2  233879
# 10      Bob       Q2  514863
# 11    Tommy       Q2  113579
# 12   Travis       Q2  266785
# 13   Donald       Q2  411379
# 14      Ted       Q2   70803
# 15      Jeb       Q2  600753
# 16    Stacy       Q2  742806
# 17   Morgan       Q2  879183
# 18    Boris       Q3  354479
# 19      Bob       Q3  297151
# 20    Tommy       Q3  430882
# 21   Travis       Q3  749238
# 22   Donald       Q3  110390
# 23      Ted       Q3  375948
# 24      Jeb       Q3  742716
# 25    Stacy       Q3  770712
# 26   Morgan       Q3   37945
# 27    Boris       Q4   32704
# 28      Bob       Q4  544493
# 29    Tommy       Q4  247231
# 30   Travis       Q4  570524
# ...

# %%
pd.melt(frame=sales,id_vars='Salesman',value_name='Quarter')
# Out:
#    Salesman variable  Quarter
# 0     Boris       Q1   602908
# 1       Bob       Q1    43790
# 2     Tommy       Q1   392668
# 3    Travis       Q1   834663
# 4    Donald       Q1   580935
# 5       Ted       Q1   656644
# 6       Jeb       Q1   486141
# 7     Stacy       Q1   479662
# 8    Morgan       Q1   992673
# 9     Boris       Q2   233879
# 10      Bob       Q2   514863
# 11    Tommy       Q2   113579
# 12   Travis       Q2   266785
# 13   Donald       Q2   411379
# 14      Ted       Q2    70803
# 15      Jeb       Q2   600753
# 16    Stacy       Q2   742806
# 17   Morgan       Q2   879183
# 18    Boris       Q3   354479
# 19      Bob       Q3   297151
# 20    Tommy       Q3   430882
# 21   Travis       Q3   749238
# 22   Donald       Q3   110390
# 23      Ted       Q3   375948
# 24      Jeb       Q3   742716
# 25    Stacy       Q3   770712
# 26   Morgan       Q3    37945
# 27    Boris       Q4    32704
# 28      Bob       Q4   544493
# 29    Tommy       Q4   247231
# ...

# %%
pd.melt(frame=sales,id_vars='Salesman',value_name='Quarter',var_name='Revenue')
# Out:
#    Salesman Revenue  Quarter
# 0     Boris      Q1   602908
# 1       Bob      Q1    43790
# 2     Tommy      Q1   392668
# 3    Travis      Q1   834663
# 4    Donald      Q1   580935
# 5       Ted      Q1   656644
# 6       Jeb      Q1   486141
# 7     Stacy      Q1   479662
# 8    Morgan      Q1   992673
# 9     Boris      Q2   233879
# 10      Bob      Q2   514863
# 11    Tommy      Q2   113579
# 12   Travis      Q2   266785
# 13   Donald      Q2   411379
# 14      Ted      Q2    70803
# 15      Jeb      Q2   600753
# 16    Stacy      Q2   742806
# 17   Morgan      Q2   879183
# 18    Boris      Q3   354479
# 19      Bob      Q3   297151
# 20    Tommy      Q3   430882
# 21   Travis      Q3   749238
# 22   Donald      Q3   110390
# 23      Ted      Q3   375948
# 24      Jeb      Q3   742716
# 25    Stacy      Q3   770712
# 26   Morgan      Q3    37945
# 27    Boris      Q4    32704
# 28      Bob      Q4   544493
# 29    Tommy      Q4   247231
# 30   Travis      Q4   570524
# ...
